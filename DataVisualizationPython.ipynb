# %%
import matplotlib.pyplot as plt

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.plot(days,max_t,color='red',marker='*',linestyle='--')

# %%
plt.plot(days,max_t,'b*--')
plt.plot(days,min_t,'k*--')
plt.plot(days,avg_t,'yd--')

# %%
import pandas as pd

# %%
df=pd.read_csv(r"home rent.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.plot(df['area'],df['price'],'bd--')

# %%
plt.scatter(df['area'],df['price'])

# %%
hour=[6,7,2,5,4]
activity=['study','sleep','excercise','cook','run']

# %%
plt.pie(hour,labels=activity,autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2586aa9dfd0>,
# ...
#  [Text(0.777817442305461, 0.7778174763049434, 'study'),
#   Text(-0.8726886607955102, 0.6696375895355182, 'sleep'),
#   Text(-0.9526282158920287, -0.5499995293510445, 'excercise'),
#   Text(-0.1435790299241716, -1.0905893187474531, 'cook'),
#   Text(0.9526278356188395, -0.5500001880037547, 'run')],
#  [Text(0.4242640594393423, 0.4242640779845145, '25.00'),
#   Text(-0.47601199679755096, 0.36525686701937354, '29.17'),
#   Text(-0.5196153904865611, -0.2999997432823879, '8.33'),
#   Text(-0.07831583450409359, -0.5948669011349744, '20.83'),
#   Text(0.5196151830648215, -0.30000010254750253, '16.67')])

# %%
c=pd.read_csv(r"Customers (1).csv")

# %%
c
# Out:
#       CustomerID  Gender  Age  Annual_Income     Profession  Work_Experience  \
# 0              1    Male   19          15000     Healthcare                1
# 1              2    Male   21          35000       Engineer                3
# 2              3  Female   20          86000       Engineer                1
# 3              4  Female   23          59000         Lawyer                0
# 4              5  Female   31          38000  Entertainment                2
# ...          ...     ...  ...            ...            ...              ...
# 1995        1996  Female   71         184387         Artist                8
# 1996        1997  Female   91          73158         Doctor                7
# 1997        1998    Male   87          90961     Healthcare                9
# 1998        1999    Male   77         182109      Executive                7
# 1999        2000    Male   90         110610  Entertainment                5
#
# ...

# %%
p=c['Gender'].value_counts()

# %%
p.index
# Out:
# Index(['Female', 'Male'], dtype='object', name='Gender')

# %%
p.values
# Out:
# array([1186,  814])

# %%
plt.pie(p.values,labels=p.index,autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2586ae05950>,
# ...
#  [Text(-0.3168321205499695, 1.0533837892182554, 'Female'),
#   Text(0.3168320870665755, -1.053383799289242, 'Male')],
#  [Text(-0.17281752029998335, 0.5745729759372301, '59.30'),
#   Text(0.17281750203631388, -0.5745729814304956, '40.70')])

# %%
d=c['Profession'].value_counts()

# %%
d.index
# Out:
# Index(['Artist', 'Healthcare', 'Entertainment', 'Engineer', 'Doctor',
#        'Executive', 'Lawyer', 'Marketing', 'Homemaker'],
#       dtype='object', name='Profession')

# %%
d.values
# Out:
# array([612, 339, 234, 179, 161, 153, 142,  85,  60])

# %%
plt.pie(d.values,labels=d.index,autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2586ad81590>,
# ...
#  [Text(0.6141397906210075, 0.9125964702846406, 'Artist'),
#   Text(-0.8805236625675836, 0.6593012055643219, 'Healthcare'),
#   Text(-1.059147070892515, -0.2969974448034971, 'Entertainment'),
#   Text(-0.6543638439293881, -0.8841990498513079, 'Engineer'),
#   Text(-0.10273115761435661, -1.095192361758981, 'Doctor'),
#   Text(0.4369437303359478, -1.009495010646465, 'Executive'),
#   Text(0.8479010771788145, -0.7007594190012763, 'Lawyer'),
#   Text(1.0414464450847887, -0.3541035187911247, 'Marketing'),
#   Text(1.0949428794639786, -0.10535696802362736, 'Homemaker')],
#  [Text(0.33498534033873134, 0.4977798928825312, '31.15'),
#   Text(-0.4802856341277728, 0.359618839398721, '17.25'),
#   Text(-0.5777165841231899, -0.16199860625645293, '11.91'),
#   Text(-0.35692573305239345, -0.4822903908279861, '9.11'),
#   Text(-0.056035176880558146, -0.597377651868535, '8.19'),
#   Text(0.23833294381960787, -0.5506336421707991, '7.79'),
# ...
